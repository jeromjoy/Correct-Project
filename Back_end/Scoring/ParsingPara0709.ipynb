# %%
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urlparse

class News:
    Article = []
    Title = ''
    Author = ''
    OriginalContent = ''
    CreatedDate = ''
    FetchedDate = ''
    ArticleUrl = ''
    LastUsed = ''
    
    def __init__(self, article , title, author, originalcontent, createddate, fetcheddate, articleurl, lastused):
        self.Article = article
        self.Title = title
        self.OriginalContent = originalcontent
        self.CreatedDate = createddate
        self.FetchedDate = fetcheddate
        self.ArticleUrl = articleurl
        self.LastUsed = lastused
        self.Author = author
    
 
def get_news_content(href):
    headers = {'user-agent' : 'Mozilla/5.0'}
    if (requests.get(href, headers = headers)):
        source = requests.get(href, headers = headers)
        if (BeautifulSoup(source.content, "lxml").body):
            soup = BeautifulSoup(source.content, "lxml").body    
            date = time.strftime('%Y-%m-%dT%H:%M:%S',time.localtime(time.time()))
            fetchedDate = date
            lastUsed = date        
            orginalContent = source.content
            print (href)
    #         print (soup.find('',{'class': 'entry'}))

            class_list = [
                        'ArticleBody__articleBody___1GSGP',#newyorker.com
                        'art-postcontent'
                        'articles2'
                        'article-inner'
                        'article-text',                    #clickhole.com,
                        'article-content',                 #fakingnews
                        'b-item__description'
                        'content-main'
                        'content-text', 
                        'content'
                        'entry-content clearfix',
                        'entry-content full-content',
                        'entry clearfix',        
                        'entry-content', 
                        'entry_content'
                        'entry-body'#www.thedailysheeple.com, waterfordwhispersnews.com, 21stcenturywire.com/
                        'entry',                           #satirewire.com, aceflashman.wordpress.com                  
                        'entry entry-content'
                        'event-text', 
                        'entry-content-text'
                        'field-item even'
                        'infopage-news'
                        'td-post-content', 
                        'the-content cf'
                        'thecontent'
                        'td-post-content td-pb-padding-side'#100percentfedup.com
                        'ntText',                          #4threvolutionarywar.wordpress.com
                        'post-single',                     #usherald.com
                        'post-content entry-content cf',   #abcnews.com.co
                        'post-body entry-content',         #aanirfan.blogspot.ie
                        'post_entry',                      #abriluno.com
                        'post-content clearfix', 
                        'post-bodycopy clearfix'
                        'post-single-content box mark-links'#americannews.com
                        'post-9141 post type-post status-publish format-standard has-post-thumbnail hentry category-world tag-fake-news tag-featured tag-satire'#theshovel.com
                        'vw-post-content clearfix'
                        'wpb_wrapper'
                        'single-box clearfix entry-content'
                        'sqs-block-content'
            ]
            article = []
            for i in range(len(class_list)):
                while (soup.find('',{'class': class_list[i]})):   
                    paragraphs = soup.find('',{'class': class_list[i]})
                    if (paragraphs.findAll('p')):
                        for paragraph in paragraphs.findAll('p'):
                            article.append(paragraph.text)

                    break
            if (article):
                print (article)
            else:
                print ('can not find paragraph')   
        else:
            print ('can not get connent')
            return
    else:
        print ('Connection refused')
 

# href = 'http://www.clickhole.com/article/heartwarming-after-teen-died-cancer-rock-stepped-a-6230'

get_news_content(href)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     390                     # otherwise it looks like a programming error was the cause.
# --> 391                     six.raise_from(e, None)
#     392         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                 try:
# --> 387                     httplib_response = conn.getresponse()
#     388                 except Exception as e:
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     333             if read is False:
# --> 334                 raise six.reraise(type(error), error, _stacktrace)
#     335             elif read is not None:
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     390                     # otherwise it looks like a programming error was the cause.
# --> 391                     six.raise_from(e, None)
#     392         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                 try:
# --> 387                     httplib_response = conn.getresponse()
#     388                 except Exception as e:
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# //anaconda/envs/py3k/lib/python3.6/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-85-27b937862f00> in <module>()
#     102 # href = 'http://www.clickhole.com/article/heartwarming-after-teen-died-cancer-rock-stepped-a-6230'
#     103 href = 'https://jonrappoport.wordpress.com/2017/07/10/the-world-is-not-you/'
# --> 104 get_news_content(href)
#     105
#     106
#
# <ipython-input-85-27b937862f00> in get_news_content(href)
#      28 def get_news_content(href):
#      29     headers = {'user-agent' : 'Mozilla/5.0'}
# ---> 30     if (requests.get(href, headers = headers)):
#      31         source = requests.get(href, headers = headers)
#      32         if (BeautifulSoup(source.content, "lxml").body):
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# //anaconda/envs/py3k/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     471
#     472         except (ProtocolError, socket.error) as err:
# --> 473             raise ConnectionError(err, request=request)
#     474
#     475         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
